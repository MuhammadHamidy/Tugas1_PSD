# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
data_PU = pd.read_csv('DatasetPU.csv')
data_PU
# Out:
#         tanggal  pm10  so2  co  o3  no2  max critical     categori location
# 0      1/1/2021    43   58  29  35   65   65       O3       SEDANG     DKI2
# 1      1/2/2021    58   86  38  64   80   86     PM25       SEDANG     DKI3
# 2      1/3/2021    64   93  25  62   86   93     PM25       SEDANG     DKI3
# 3      1/4/2021    50   67  24  31   77   77       O3       SEDANG     DKI2
# 4      1/5/2021    59   89  24  35   77   89     PM25       SEDANG     DKI3
# ..          ...   ...  ...  ..  ..  ...  ...      ...          ...      ...
# 360  12/27/2021    75  121  61  23   40   47     PM25  TIDAK SEHAT     DKI4
# 361  12/28/2021    59   89  53  16   34   33     PM25       SEDANG     DKI4
# 362  12/29/2021    61   98  54  15   37   29     PM25       SEDANG     DKI4
# 363  12/30/2021    60  102  53  17   38   44     PM25  TIDAK SEHAT     DKI4
# 364  12/31/2021    64   90  52  44   37   53     PM25       SEDANG     DKI4
#
# [365 rows x 10 columns]

# %%
data_PU.sort_values(["categori"], axis = 0, ascending=[True], inplace=True)
data_PU
# Out:
#         tanggal  pm10  so2  co  o3  no2  max critical     categori location
# 331  11/28/2021    19   33  41   7   47   10       O3         BAIK     DKI2
# 322  11/19/2021    32   45  41   7   42   12     PM25         BAIK     DKI2
# 325  11/22/2021    29   45  42   7   41   12     PM25         BAIK     DKI4
# 310   11/7/2021    52   81  51  10   55   25     PM25       SEDANG     DKI4
# 0      1/1/2021    43   58  29  35   65   65       O3       SEDANG     DKI2
# ..          ...   ...  ...  ..  ..  ...  ...      ...          ...      ...
# 254   9/12/2021    66  111  51  10   36   27     PM25  TIDAK SEHAT     DKI4
# 253   9/11/2021    70  109  53  12   46   41     PM25  TIDAK SEHAT     DKI4
# 195   7/15/2021    95  174  62  15   56   30     PM25  TIDAK SEHAT     DKI4
# 76    3/18/2021    78  125  45  16   74   40     PM25  TIDAK SEHAT     DKI4
# 182    7/2/2021    68  108  56  23   40   51     PM25  TIDAK SEHAT     DKI4
#
# [365 rows x 10 columns]

# %%
data_PU.sort_values(["tanggal"], axis = 0, ascending=[True], inplace=True)
data_PU
# Out:
#        tanggal  pm10  so2  co  o3  no2  max critical     categori location
# 0     1/1/2021    43   58  29  35   65   65       O3       SEDANG     DKI2
# 9    1/10/2021    24   39  16  38   59   59       O3       SEDANG     DKI2
# 10   1/11/2021    51   72  17  57   68   72     PM25       SEDANG     DKI3
# 11   1/12/2021    29   58  20  44   77   77       O3       SEDANG     DKI2
# 12   1/13/2021    36   47  17  32   68   68       O3       SEDANG     DKI2
# ..         ...   ...  ...  ..  ..  ...  ...      ...          ...      ...
# 247   9/5/2021    74  120  52  12   36   28     PM25  TIDAK SEHAT     DKI4
# 248   9/6/2021    73  109  51  13   34   24     PM25  TIDAK SEHAT     DKI4
# 249   9/7/2021    60   86  51  11   27   24     PM25       SEDANG     DKI4
# 250   9/8/2021    64  106  52  16   29   34     PM25  TIDAK SEHAT     DKI4
# 251   9/9/2021    68   88  54  12   35   31     PM25       SEDANG     DKI2
#
# [365 rows x 10 columns]

# %%
plt.plot(data_PU['tanggal'], data_PU['max'])
plt.show()

# %%
plt.plot(data_PU['tanggal'], data_PU['categori'])
plt.show()
